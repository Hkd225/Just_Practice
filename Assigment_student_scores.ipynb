# %% [markdown]
# <a href="https://colab.research.google.com/github/Hkd225/Just_Practice/blob/main/Assigment_student_scores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries and resources
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

# %%
import pandas as pd
# Link asli:
# https://docs.google.com/spreadsheets/d/1_JJ3hDt-apvtmAnjZM6-QeHD27tfNNRv/edit?gid=610198973#gid=610198973
url = 'https://docs.google.com/spreadsheets/d/1_JJ3hDt-apvtmAnjZM6-QeHD27tfNNRv/export?format=csv&gid=610198973'

data = pd.read_csv(url)

# %%
#menampilkan data 7 teratas dalam file
data.head()
# Out:
#    Hours (x)  Scores (y)
# 0        2.5          21
# 1        5.1          47
# 2        3.2          27
# 3        8.5          75
# 4        3.5          30

# %%
#mendapatkan informasi dari data yang ada
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hours (x)   25 non-null     float64
#  1   Scores (y)  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 532.0 bytes

# %%
#menjelaskan statistik dasar di balik kumpulan data yang digunakan
data.describe()
# Out:
#        Hours (x)  Scores (y)
# count  25.000000   25.000000
# mean    5.012000   51.480000
# std     2.525094   25.286887
# min     1.100000   17.000000
# 25%     2.700000   30.000000
# 50%     4.800000   47.000000
# 75%     7.400000   75.000000
# max     9.200000   95.000000

# %%
# melihat kesebaran titik yang ada pada grafik
plt.figure(figsize=(12,6))
sns.pairplot(data,x_vars=('Hours (x)'), y_vars=('Scores (y)'), size=7,kind='scatter')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.title('Scores Prediction')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df=data.copy()

# %%
#cek data duplikat
print("Data Sebelum Pemeriksaan Duplikat:")
print(df.shape)
# Out:
# Data Sebelum Pemeriksaan Duplikat:
# (25, 2)

# %%
duplicate_rows_before = df[df.duplicated()]
duplicate_rows_before
# Out:
# Empty DataFrame
# Columns: [Hours (x), Scores (y)]
# Index: []

# %%
#jika ada duplicate
df = df.drop_duplicates()

# %%
print("\nData Setelah Pemeriksaan Duplikat:")
print(df.shape)
# Out:
# Data Setelah Pemeriksaan Duplikat:
# (25, 2)

# %%
df.isna().sum()
# Out:
# Hours (x)     0
# Scores (y)    0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Outlier Analysis
sns.boxplot(x="Hours (x)", data=df)

# Menambahkan label sumbu dan judul
plt.xlabel("Years of Hours (x)")
plt.ylabel("Frequency")

# Menampilkan plot
plt.show()

# %%
# Data waktu
X = df['Hours (x)']
X.head()
# Out:
# 0    2.5
# 1    5.1
# 2    3.2
# 3    8.5
# 4    3.5
# Name: Hours (x), dtype: float64

# %%
#Data Scores
Y = df['Scores (y)']
Y.head()
# Out:
# 0    21
# 1    47
# 2    27
# 3    75
# 4    30
# Name: Scores (y), dtype: int64

# %%
#masukkan model train 1
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,Y,train_size=0.75,random_state=42)

# %%
X_train
# Out:
# 1     5.1
# 22    3.8
# 5     1.5
# 2     3.2
# 12    4.5
# 15    8.9
# 3     8.5
# 4     3.5
# 20    2.7
# 17    1.9
# 21    4.8
# 18    6.1
# 24    7.8
# 7     5.5
# 10    7.7
# 14    1.1
# 19    7.4
# 6     9.2
# Name: Hours (x), dtype: float64

# %%
X_test
# Out:
# 8     8.3
# 16    2.5
# 0     2.5
# 23    6.9
# 11    5.9
# 9     2.7
# 13    3.3
# Name: Hours (x), dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
# Create new axis for x column in array
import numpy as np
# Convert X_train and X_test to NumPy arrays
X_train = X_train.to_numpy() # Kolom x nya ada 1 saja, jika lebih dari 1 untuk x nya maka tidak code to_numpy() dibiarkan dalam bentuk dataframe
X_test = X_test.to_numpy()

# Add new axis to the end
X_train = X_train[:, np.newaxis]
X_test = X_test[:, np.newaxis]

# %%
X_train
# Out:
# array([[5.1],
#        [3.8],
#        [1.5],
#        [3.2],
#        [4.5],
#        [8.9],
#        [8.5],
#        [3.5],
#        [2.7],
#        [1.9],
#        [4.8],
#        [6.1],
#        [7.8],
#        [5.5],
#        [7.7],
#        [1.1],
#        [7.4],
#        [9.2]])

# %%
X_test
# Out:
# array([[8.3],
#        [2.5],
#        [2.5],
#        [6.9],
#        [5.9],
#        [2.7],
#        [3.3]])

# %%
y_train
# Out:
# 1     47
# 22    35
# 5     20
# 2     27
# 12    41
# 15    95
# 3     75
# 4     30
# 20    30
# 17    24
# 21    54
# 18    67
# 24    86
# 7     60
# 10    85
# 14    17
# 19    69
# 6     88
# Name: Scores (y), dtype: int64

# %%
y_test
# Out:
# 8     81
# 16    30
# 0     21
# 23    76
# 11    62
# 9     25
# 13    42
# Name: Scores (y), dtype: int64

# %%
lr_model = LinearRegression() # Mahasiswa A
lr_model.fit(X_train,y_train) # Belajar
# Out:
# LinearRegression()

# %%
y_pred_train = lr_model.predict(X_train)
y_pred_train
# Out:
# array([52.02223727, 39.39391742, 17.05150538, 33.56546211, 46.19378196,
#        88.93578761, 85.05015073, 36.47968977, 28.70841601, 20.93714226,
#        49.10800962, 61.73632947, 78.25028619, 55.90787415, 77.27887697,
#        13.1658685 , 74.36464932, 91.85001526])

# %%
y_train
# Out:
# 1     47
# 22    35
# 5     20
# 2     27
# 12    41
# 15    95
# 3     75
# 4     30
# 20    30
# 17    24
# 21    54
# 18    67
# 24    86
# 7     60
# 10    85
# 14    17
# 19    69
# 6     88
# Name: Scores (y), dtype: int64

# %%
y_pred = lr_model.predict(X_test)

# %%
X_test
# Out:
# array([[8.3],
#        [2.5],
#        [2.5],
#        [6.9],
#        [5.9],
#        [2.7],
#        [3.3]])

# %%
y_pred
# Out:
# array([83.10733229, 26.76559757, 26.76559757, 69.50760322, 59.79351103,
#        28.70841601, 34.53687133])

# %%
c = [i for i in range (1,len(y_test)+1,1)]
plt.plot(c,y_test,color='r',linestyle='-',label='Actual Data')
plt.plot(c,y_pred,color='b',linestyle='dashed',label='Prediction')
plt.xlabel('Scores')
plt.ylabel('index')
plt.title('Prediction with Linear Regression')
plt.legend()
plt.show()

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
rsq = r2_score(y_test,y_pred)

# %%
print('r square Linear Regression:',rsq)
# Out:
# r square Linear Regression: 0.9553509219739938

# %%
print('Intercept of the Linear Regression model:',lr_model.intercept_)
print('Coefficient of the line Linear Regression:',lr_model.coef_)
# Out:
# Intercept of the Linear Regression model: 2.4803670915057623
# Coefficient of the line Linear Regression: [9.71409219]

# %% [markdown]
# # Garis dengan regresi Linear
#
# # Y = 2.480 + 9.714x

# %%
# y_test = 81
# X_test = 8.3
# y = 2.480 + 9.714 * 8.3
nilai_y = 2.480 + 9.714 * 8.3
print(nilai_y)
# Out:
# 83.10620000000002

# %% [markdown]
# # Decission Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt_model = DecisionTreeRegressor()
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_dt = dt_model.predict(X_test)

# %%
y_pred_dt
# Out:
# array([75., 30., 30., 69., 67., 30., 27.])

# %%
y_test
# Out:
# 8     81
# 16    30
# 0     21
# 23    76
# 11    62
# 9     25
# 13    42
# Name: Scores (y), dtype: int64

# %%
X_test
# Out:
# array([[8.3],
#        [2.5],
#        [2.5],
#        [6.9],
#        [5.9],
#        [2.7],
#        [3.3]])

# %%
c = [i for i in range (1,len(y_test)+1,1)]
plt.plot(c,y_test,color='r',linestyle='-',label='Actual Data')
plt.plot(c,y_pred_dt,color='b',linestyle='dashed',label='Prediction')
plt.xlabel('Scores')
plt.ylabel('index')
plt.title('Prediction with Linear Regression')
plt.legend()
plt.show()

# %%
rsq_dt = r2_score(y_test,y_pred_dt)

# %%
print('r square Decision Tree Results:',rsq_dt)
# Out:
# r square Decision Tree Results: 0.8803859268443893

# %% [markdown]
# #Forrest regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_rf = RandomForestRegressor()
model_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_rf = model_rf.predict(X_test)

# %%
y_pred_rf
# Out:
# array([80.38, 27.94, 27.94, 71.71, 63.6 , 29.04, 29.23])

# %%
y_test
# Out:
# 8     81
# 16    30
# 0     21
# 23    76
# 11    62
# 9     25
# 13    42
# Name: Scores (y), dtype: int64

# %%
X_test
# Out:
# array([[8.3],
#        [2.5],
#        [2.5],
#        [6.9],
#        [5.9],
#        [2.7],
#        [3.3]])

# %%
c = [i for i in range (1,len(y_test)+1,1)]
plt.plot(c,y_test,color='r',linestyle='-',label='Actual Data')
plt.plot(c,y_pred_rf,color='b',linestyle='dashed',label='Prediction')
plt.xlabel('Scores')
plt.ylabel('index')
plt.title('Prediction with Linear Regression')
plt.legend()
plt.show()

# %%
rsq_df = r2_score(y_test,y_pred_rf)

# %%
print('r square Decision Forest Results:',rsq_df)
# Out:
# r square Decision Forest Results: 0.9313371280223186
